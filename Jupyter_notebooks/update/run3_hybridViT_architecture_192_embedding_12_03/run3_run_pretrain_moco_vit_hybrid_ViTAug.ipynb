# %% [markdown]
# # Project UPDATE for ViT Hybrid (ConvStems) Setup:
#
# ### Architecture
# Run pre-training with contrastive learning (MoCo framework)
# * Use backbone - `ViT Hybrid`
# * **Perform SSL Pre-training** of backbone using contrastive learning (MoCo) -> augment medical imaging dataset (Chest XRs) (Pre-text task); create positive and negative pairs
#   * Produce: `moco_vit_hybrid_encoder.pth`
# * **Transfer Learning:** Fine-tune pre-trained ResNet for Pneumonia Chest XR classification
#   * Produce: `finetuned_vit_hybrid_medical.pth`
#
# ### Pre-training Dataset: CheXpert
# * Subset: Pneumonia classification only; smaller dataset (to accomodate class imbalance)
#
# ### Fine-tuning Dataset: NIH Pneumonia Dataset

# %% [markdown]
# ###

# %%
# import libraries
import os
import sys
import argparse
from tqdm import tqdm

import numpy as np
import seaborn as sns
import pandas as pd
import math
from copy import deepcopy

# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import display

import pickle
from datetime import datetime

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import random_split, DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Collab Needs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Define filepaths to required input (scripts, data) and outputs

# %%
# ----------------------------------------------------
# Inputs root
# ----------------------------------------------------
FP_ROOT="/content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/"

# ----------------------------------------------------
# Dataset info
# ----------------------------------------------------
# Chexpert
DATASET_PATH_SPLIT = FP_ROOT + "Data/CheXpert_reduced_dataset_split_v3.zip"

# ChexPert
TRAIN_LABELS_CSV = FP_ROOT + "Data/1_final_project_updated_names_train_moco.csv"
TEST_LABELS_CSV = FP_ROOT + "Data/1_final_project_updated_names_test_moco.csv"

LINEAR_TRAIN_LABELS_CSV = FP_ROOT + "Data/2_final_project_updated_names_train_linear.csv"
LINEAR_TEST_LABELS_CSV = FP_ROOT + "Data/2_final_project_updated_names_test_linear.csv"

# ----------------------------------------------------
# Model SRC
# ----------------------------------------------------
SRC_ROOT = FP_ROOT + "src/"
TRAIN_SCRIPT = f"{SRC_ROOT}/train_moco.py"
MOCO_FOLDER = f"{SRC_ROOT}/moco"

# ----------------------------------------------------
# Outputs
# ----------------------------------------------------
ROOT_ARTIFACT_SAVE = FP_ROOT + "artifacts/"

# %%
# Add the project /src to the system path
if SRC_ROOT not in sys.path:
    sys.path.append(SRC_ROOT)
    print(f"Added {SRC_ROOT} to sys.path")
# Out:
# Added /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/src/ to sys.path

# %%
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython', '/tmp/tmpi0b1067y', '/content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/src/']

# %% [markdown]
# ## Unzip data

# %% [markdown]
# ChexPert

# %%
# Unzip the dataset (image) files to /tmp
DATA_DEST_UNZIPPED = "/tmp/CheXpert_dataset/"
os.makedirs(DATA_DEST_UNZIPPED, exist_ok=True)
# !unzip "{DATASET_PATH_SPLIT}" -d {DATA_DEST_UNZIPPED} # need to use "" to accomdate space
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49868_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49869_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49869_study1_view2_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49869_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49873_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49878_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49879_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49879_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49880_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49883_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49885_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49885_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49886_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49886_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49886_study8_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49890_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49892_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49898_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49901_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49901_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49901_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49906_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49906_study6_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49908_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49911_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49915_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49918_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49923_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49926_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49928_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49930_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49930_study3_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49932_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49933_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49933_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49933_study3_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49938_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49938_study1_view2_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49938_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49938_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49943_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49944_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49951_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49951_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49953_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49955_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49968_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49970_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49972_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49974_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49975_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49977_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49978_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49978_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49979_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49980_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49980_study2_view2_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49980_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49985_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49987_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient49997_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50005_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50005_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50007_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50008_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50009_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50013_study1_view3_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50015_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50016_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50022_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50022_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50023_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50027_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50029_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50031_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50035_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50035_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50038_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50041_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50042_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50055_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50061_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50063_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50063_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50064_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50065_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50065_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50065_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50067_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50070_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50070_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50071_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50071_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50074_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50077_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50079_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50079_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50086_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50087_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50088_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50090_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50093_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50093_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50094_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50103_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50106_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50110_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50112_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50113_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50118_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50118_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50123_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50124_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50130_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50130_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50131_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50134_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50135_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50139_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50148_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50160_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50161_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50163_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50165_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50168_study11_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50168_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50168_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50168_study7_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50170_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50172_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50173_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50184_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50186_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50186_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50189_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50193_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50193_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50193_study6_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50193_study7_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50194_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50195_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50196_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50198_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50198_study2_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50204_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50204_study2_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50204_study6_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50208_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50208_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50209_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50210_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50212_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50212_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50213_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50213_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50216_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50216_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50218_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50221_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50223_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50225_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50226_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50228_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50230_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50231_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50237_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50238_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50243_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50243_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50243_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50245_study1_view2_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50253_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50253_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50258_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50259_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50262_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50263_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50264_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50265_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50266_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50267_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50267_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50267_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50267_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50270_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50271_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50272_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50273_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50274_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50275_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50276_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50279_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50280_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50283_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50284_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50297_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50305_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50306_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50306_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50307_study1_view2_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50308_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50308_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50309_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50312_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50312_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50314_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50315_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50317_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50317_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50317_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50318_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50324_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50325_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50328_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50329_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50331_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50332_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50332_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50337_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50340_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50340_study6_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50341_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50343_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50344_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50345_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50347_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50348_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50349_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50350_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50350_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50356_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50357_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50357_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50357_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50357_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50357_study7_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50358_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50360_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50361_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50363_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50365_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50366_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50367_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50375_study3_view2_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50376_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50377_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50378_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50380_study3_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50387_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50389_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50395_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50398_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50398_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50399_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50401_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50401_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50403_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50405_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50405_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50405_study7_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50407_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50407_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50408_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50408_study3_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50409_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50414_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50419_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50422_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50424_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50424_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50424_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50425_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50426_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50427_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50428_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50429_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50429_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50429_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50430_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50432_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50434_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50434_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50434_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50436_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50440_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50442_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50447_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50451_study3_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50456_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50456_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50458_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50464_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50464_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50467_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50474_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50475_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50477_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50477_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50477_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50477_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50478_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50481_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50483_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50484_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50488_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50488_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50488_study7_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50490_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50490_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50491_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50497_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50498_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50507_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50507_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50509_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50513_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50513_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50515_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50515_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50517_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50521_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50523_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50524_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50534_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50536_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50538_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50541_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50542_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50544_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50547_study1_view3_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50549_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50550_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50551_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50552_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50552_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50553_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50555_study2_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50557_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50557_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50560_study10_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50560_study11_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50560_study12_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50563_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50568_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50571_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50575_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50576_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50580_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50581_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50582_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50586_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50588_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50589_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50589_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50589_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50595_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50596_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50596_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50596_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50599_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50599_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50600_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50602_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50602_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50605_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50607_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50616_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50617_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50619_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50620_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50621_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50623_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50623_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50627_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50627_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50628_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50628_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50629_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50629_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50629_study1_view3_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50636_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50641_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50646_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50646_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50647_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50648_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50650_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50652_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50653_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50653_study6_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50654_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50655_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50655_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50659_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50659_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50660_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50663_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50663_study6_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50667_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50668_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50673_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50676_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50676_study1_view2_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50682_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50684_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50689_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50691_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50693_study3_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50693_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50694_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50694_study1_view2_lateral.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50699_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50701_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50703_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50704_study5_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient50714_study1_view1_frontal.jpg
# ...
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63928_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63934_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63938_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63939_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63941_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63943_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63945_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63961_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63962_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63970_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63971_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63972_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63975_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient63991_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64000_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64000_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64010_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64011_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64014_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64016_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64030_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64034_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64038_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64039_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64040_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64045_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64048_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64049_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64055_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64060_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64067_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64068_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64072_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64073_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64074_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64084_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64084_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64089_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64103_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64106_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64107_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64112_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64114_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64127_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64134_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64143_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64143_study1_view2_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64144_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64145_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64146_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64149_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64150_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64153_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64160_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64177_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64179_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64181_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64188_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64190_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64193_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64195_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64200_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64201_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64209_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64213_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64215_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64216_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64247_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64248_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64256_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64267_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64268_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64274_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64289_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64290_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64295_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64297_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64301_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64303_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64307_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64312_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64325_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64326_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64333_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64341_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64342_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64350_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64354_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64356_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64376_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64377_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64383_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64397_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64400_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64401_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64404_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64406_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64416_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64420_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64422_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64426_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64428_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64433_study1_view2_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64435_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64438_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64449_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64451_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64455_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64461_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64462_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64467_study4_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64468_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64471_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64472_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64482_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64487_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64488_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64492_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64497_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64501_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64503_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64505_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64509_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64509_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64510_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64515_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64520_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64526_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64527_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64533_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64536_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64537_study2_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64548_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64552_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64583_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64652_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64689_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64692_study1_view1_frontal.jpg
#   inflating: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train/patient64715_study1_view1_frontal.jpg

# %%
# Update for the unzipped sub-name
DATA_DEST_UNZIPPED = "/tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/"

# %% [markdown]
# ## 1) Run Pre-training - Contrastive Learning

# %%
# Run from the src directory
# %cd "/content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/src"
# Out:
# /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/src

# %%
# Hyperparams
batch_size = 64

# %%
! python moco/train_moco_vit_hybrid.py \
    --train_csv_path "$TRAIN_LABELS_CSV" \
    --test_csv_path "$TEST_LABELS_CSV" \
    --root_dir "$DATA_DEST_UNZIPPED" \
    --artifact_root "$ROOT_ARTIFACT_SAVE" \
    --batch_size "$batch_size" \
    --n_epochs 15 \
    --test_num_classes 2 \
    --linear_n_epochs 10 \
    --linear_train_csv_path "$LINEAR_TRAIN_LABELS_CSV" \
    --linear_test_csv_path "$LINEAR_TEST_LABELS_CSV" \
    --model_type "VIT_Hybrid" \
    --out_model_name "vit_hybrid_moco_encoder_v3.pth" \
    --embedding_dim 192
# Out:
# Created log file:  /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts/moco_training_log_20251204_024027.txt
# [2025-12-04 02:40:27] Creating MoCo medical image Train DataLoader (Hybrid ViT)... : from /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/Data/1_final_project_updated_names_train_moco.csv
# Creating MoCo DataLoader for train data...
# CSV Path: /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/Data/1_final_project_updated_names_train_moco.csv
# Image Root Dir: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/
# Loading dataset from: /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/Data/1_final_project_updated_names_train_moco.csv
# Training Dataset size: 49500 images
# Data Sample q shape: torch.Size([3, 224, 224]), Sample k shape: torch.Size([3, 224, 224])
# [2025-12-04 02:40:27] Using ViT Hybrid backbone for MoCo
# [2025-12-04 02:40:27] Note: No option to use pretrained weights; ignoring if set
# [2025-12-04 02:40:27] Starting MoCo ViT Hybrid training for 15 epochs...
# Epoch 0/14: 100% 773/773 [16:10<00:00,  1.25s/it, loss=8.1]
# [2025-12-04 02:56:38] Epoch complete 0, Avg. Running Loss: 8.023569
# [2025-12-04 02:56:38] Saving initial checkpoint at epoch 1; Avg. Running Loss: 8.023569; Last Loss: 8.103824
# [2025-12-04 02:56:38] Saving checkpoint at epoch 1; /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//vit_hybrid_moco_checkpoint_epoch_1.pth
# Epoch 1/14: 100% 773/773 [16:10<00:00,  1.25s/it, loss=7.69]
# [2025-12-04 03:12:48] Epoch complete 1, Avg. Running Loss: 8.056590
# Epoch 2/14: 100% 773/773 [16:09<00:00,  1.25s/it, loss=7.93]
# [2025-12-04 03:28:58] Epoch complete 2, Avg. Running Loss: 7.919313
# [2025-12-04 03:28:58] Loss improved from 8.023569 to 7.919313. Saving checkpoint.
# [2025-12-04 03:28:58] Saving checkpoint at epoch 3; /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//vit_hybrid_moco_checkpoint_epoch_3.pth
# Epoch 3/14: 100% 773/773 [16:10<00:00,  1.25s/it, loss=7.85]
# [2025-12-04 03:45:08] Epoch complete 3, Avg. Running Loss: 7.830574
# [2025-12-04 03:45:08] Loss improved from 7.919313 to 7.830574. Saving checkpoint.
# [2025-12-04 03:45:08] Saving checkpoint at epoch 4; /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//vit_hybrid_moco_checkpoint_epoch_4.pth
# Epoch 4/14: 100% 773/773 [16:10<00:00,  1.25s/it, loss=7.8]
# [2025-12-04 04:01:18] Epoch complete 4, Avg. Running Loss: 7.854099
# [2025-12-04 04:01:18] Loss improved from 7.830574 to 7.854099. Saving checkpoint.
# [2025-12-04 04:01:18] Saving checkpoint at epoch 5; /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//vit_hybrid_moco_checkpoint_epoch_5.pth
# Epoch 5/14: 100% 773/773 [16:10<00:00,  1.25s/it, loss=7.79]
# [2025-12-04 04:17:29] Epoch complete 5, Avg. Running Loss: 7.764595
# [2025-12-04 04:17:29] Loss improved from 7.854099 to 7.764595. Saving checkpoint.
# [2025-12-04 04:17:29] Saving checkpoint at epoch 6; /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//vit_hybrid_moco_checkpoint_epoch_6.pth
# Epoch 6/14: 100% 773/773 [16:10<00:00,  1.26s/it, loss=7.76]
# [2025-12-04 04:33:39] Epoch complete 6, Avg. Running Loss: 7.781360
# Epoch 7/14: 100% 773/773 [16:10<00:00,  1.26s/it, loss=7.67]
# [2025-12-04 04:49:50] Epoch complete 7, Avg. Running Loss: 7.750602
# [2025-12-04 04:49:50] Loss improved from 7.764595 to 7.750602. Saving checkpoint.
# [2025-12-04 04:49:50] Saving checkpoint at epoch 8; /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//vit_hybrid_moco_checkpoint_epoch_8.pth
# Epoch 8/14: 100% 773/773 [16:10<00:00,  1.26s/it, loss=7.68]
# [2025-12-04 05:06:01] Epoch complete 8, Avg. Running Loss: 7.732896
# [2025-12-04 05:06:01] Loss improved from 7.750602 to 7.732896. Saving checkpoint.
# [2025-12-04 05:06:01] Saving checkpoint at epoch 9; /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//vit_hybrid_moco_checkpoint_epoch_9.pth
# Epoch 9/14: 100% 773/773 [16:09<00:00,  1.25s/it, loss=7.69]
# [2025-12-04 05:22:11] Epoch complete 9, Avg. Running Loss: 7.718834
# [2025-12-04 05:22:11] Loss improved from 7.732896 to 7.718834. Saving checkpoint.
# [2025-12-04 05:22:11] Saving checkpoint at epoch 10; /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//vit_hybrid_moco_checkpoint_epoch_10.pth
# Epoch 10/14: 100% 773/773 [16:10<00:00,  1.26s/it, loss=7.72]
# [2025-12-04 05:38:22] Epoch complete 10, Avg. Running Loss: 7.681418
# [2025-12-04 05:38:22] Loss improved from 7.718834 to 7.681418. Saving checkpoint.
# [2025-12-04 05:38:22] Saving checkpoint at epoch 11; /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//vit_hybrid_moco_checkpoint_epoch_11.pth
# Epoch 11/14: 100% 773/773 [16:09<00:00,  1.25s/it, loss=7.68]
# [2025-12-04 05:54:32] Epoch complete 11, Avg. Running Loss: 7.700110
# Epoch 12/14: 100% 773/773 [16:09<00:00,  1.25s/it, loss=7.67]
# [2025-12-04 06:10:42] Epoch complete 12, Avg. Running Loss: 7.665923
# [2025-12-04 06:10:42] Loss improved from 7.681418 to 7.665923. Saving checkpoint.
# [2025-12-04 06:10:42] Saving checkpoint at epoch 13; /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//vit_hybrid_moco_checkpoint_epoch_13.pth
# Epoch 13/14: 100% 773/773 [16:09<00:00,  1.25s/it, loss=7.62]
# [2025-12-04 06:26:51] Epoch complete 13, Avg. Running Loss: 7.664934
# [2025-12-04 06:26:51] Loss improved from 7.665923 to 7.664934. Saving checkpoint.
# [2025-12-04 06:26:51] Saving checkpoint at epoch 14; /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//vit_hybrid_moco_checkpoint_epoch_14.pth
# Epoch 14/14: 100% 773/773 [16:06<00:00,  1.25s/it, loss=7.69]
# [2025-12-04 06:42:59] Epoch complete 14, Avg. Running Loss: 7.665352
# [2025-12-04 06:42:59] Loss improved from 7.664934 to 7.665352. Saving checkpoint.
# [2025-12-04 06:42:59] Saving checkpoint at epoch 15; /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//vit_hybrid_moco_checkpoint_epoch_15.pth
# [2025-12-04 06:42:59] MoCo training complete!!
# [2025-12-04 06:42:59] Saved pretrained encoder to /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts/vit_hybrid_moco_encoder_v3.pth
# [2025-12-04 06:42:59] Saved training stats to /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//pretrain_stats_training.json

# %% [markdown]
# ## Test Backbone with Linear Classifier

# %%
# Run from the src directory
# %cd "/content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/src"

# Hyperparams
batch_size = 128
# Out:
# /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/src

# %%
! python moco/test_moco_vit_hybrid.py \
    --root_dir "$DATA_DEST_UNZIPPED" \
    --artifact_root "$ROOT_ARTIFACT_SAVE" \
    --test_num_classes 2 \
    --linear_n_epochs 10 \
    --linear_train_csv_path "$LINEAR_TRAIN_LABELS_CSV" \
    --linear_test_csv_path "$LINEAR_TEST_LABELS_CSV" \
    --model_checkpoint "vit_hybrid_moco_encoder_v3.pth" \
    --batch_size "$batch_size"
# Out:
# Created log file:  /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts/moco_backbone_testing_log_20251204_064801.txt
# [2025-12-04 06:48:01] Starting MoCo backbone testing...
# [2025-12-04 06:48:01] Loading pretrained MoCo model from /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts/vit_hybrid_moco_encoder_v3.pth...
# [2025-12-04 06:48:01] Loaded model. Missing keys: ['queue', 'queue_ptr', 'patch_embed.proj.0.weight', 'patch_embed.proj.0.bias', 'patch_embed.proj.2.weight', 'patch_embed.proj.2.bias', 'patch_embed.proj.4.weight', 'patch_embed.proj.4.bias', 'pos_encoding.pos_embed', 'pos_encoding.cls_token', 'transformer.encoder.layers.0.self_attn.in_proj_weight', 'transformer.encoder.layers.0.self_attn.in_proj_bias', 'transformer.encoder.layers.0.self_attn.out_proj.weight', 'transformer.encoder.layers.0.self_attn.out_proj.bias', 'transformer.encoder.layers.0.linear1.weight', 'transformer.encoder.layers.0.linear1.bias', 'transformer.encoder.layers.0.linear2.weight', 'transformer.encoder.layers.0.linear2.bias', 'transformer.encoder.layers.0.norm1.weight', 'transformer.encoder.layers.0.norm1.bias', 'transformer.encoder.layers.0.norm2.weight', 'transformer.encoder.layers.0.norm2.bias', 'transformer.encoder.layers.1.self_attn.in_proj_weight', 'transformer.encoder.layers.1.self_attn.in_proj_bias', 'transformer.encoder.layers.1.self_attn.out_proj.weight', 'transformer.encoder.layers.1.self_attn.out_proj.bias', 'transformer.encoder.layers.1.linear1.weight', 'transformer.encoder.layers.1.linear1.bias', 'transformer.encoder.layers.1.linear2.weight', 'transformer.encoder.layers.1.linear2.bias', 'transformer.encoder.layers.1.norm1.weight', 'transformer.encoder.layers.1.norm1.bias', 'transformer.encoder.layers.1.norm2.weight', 'transformer.encoder.layers.1.norm2.bias', 'transformer.encoder.layers.2.self_attn.in_proj_weight', 'transformer.encoder.layers.2.self_attn.in_proj_bias', 'transformer.encoder.layers.2.self_attn.out_proj.weight', 'transformer.encoder.layers.2.self_attn.out_proj.bias', 'transformer.encoder.layers.2.linear1.weight', 'transformer.encoder.layers.2.linear1.bias', 'transformer.encoder.layers.2.linear2.weight', 'transformer.encoder.layers.2.linear2.bias', 'transformer.encoder.layers.2.norm1.weight', 'transformer.encoder.layers.2.norm1.bias', 'transformer.encoder.layers.2.norm2.weight', 'transformer.encoder.layers.2.norm2.bias', 'transformer.encoder.layers.3.self_attn.in_proj_weight', 'transformer.encoder.layers.3.self_attn.in_proj_bias', 'transformer.encoder.layers.3.self_attn.out_proj.weight', 'transformer.encoder.layers.3.self_attn.out_proj.bias', 'transformer.encoder.layers.3.linear1.weight', 'transformer.encoder.layers.3.linear1.bias', 'transformer.encoder.layers.3.linear2.weight', 'transformer.encoder.layers.3.linear2.bias', 'transformer.encoder.layers.3.norm1.weight', 'transformer.encoder.layers.3.norm1.bias', 'transformer.encoder.layers.3.norm2.weight', 'transformer.encoder.layers.3.norm2.bias', 'transformer.encoder.layers.4.self_attn.in_proj_weight', 'transformer.encoder.layers.4.self_attn.in_proj_bias', 'transformer.encoder.layers.4.self_attn.out_proj.weight', 'transformer.encoder.layers.4.self_attn.out_proj.bias', 'transformer.encoder.layers.4.linear1.weight', 'transformer.encoder.layers.4.linear1.bias', 'transformer.encoder.layers.4.linear2.weight', 'transformer.encoder.layers.4.linear2.bias', 'transformer.encoder.layers.4.norm1.weight', 'transformer.encoder.layers.4.norm1.bias', 'transformer.encoder.layers.4.norm2.weight', 'transformer.encoder.layers.4.norm2.bias', 'transformer.encoder.layers.5.self_attn.in_proj_weight', 'transformer.encoder.layers.5.self_attn.in_proj_bias', 'transformer.encoder.layers.5.self_attn.out_proj.weight', 'transformer.encoder.layers.5.self_attn.out_proj.bias', 'transformer.encoder.layers.5.linear1.weight', 'transformer.encoder.layers.5.linear1.bias', 'transformer.encoder.layers.5.linear2.weight', 'transformer.encoder.layers.5.linear2.bias', 'transformer.encoder.layers.5.norm1.weight', 'transformer.encoder.layers.5.norm1.bias', 'transformer.encoder.layers.5.norm2.weight', 'transformer.encoder.layers.5.norm2.bias', 'transformer.encoder.layers.6.self_attn.in_proj_weight', 'transformer.encoder.layers.6.self_attn.in_proj_bias', 'transformer.encoder.layers.6.self_attn.out_proj.weight', 'transformer.encoder. ...
# [2025-12-04 06:48:02] Loaded pretrained encoder. missing keys: ['queue', 'queue_ptr', 'patch_embed.proj.0.weight', 'patch_embed.proj.0.bias', 'patch_embed.proj.2.weight', 'patch_embed.proj.2.bias', 'patch_embed.proj.4.weight', 'patch_embed.proj.4.bias', 'pos_encoding.pos_embed', 'pos_encoding.cls_token', 'transformer.encoder.layers.0.self_attn.in_proj_weight', 'transformer.encoder.layers.0.self_attn.in_proj_bias', 'transformer.encoder.layers.0.self_attn.out_proj.weight', 'transformer.encoder.layers.0.self_attn.out_proj.bias', 'transformer.encoder.layers.0.linear1.weight', 'transformer.encoder.layers.0.linear1.bias', 'transformer.encoder.layers.0.linear2.weight', 'transformer.encoder.layers.0.linear2.bias', 'transformer.encoder.layers.0.norm1.weight', 'transformer.encoder.layers.0.norm1.bias', 'transformer.encoder.layers.0.norm2.weight', 'transformer.encoder.layers.0.norm2.bias', 'transformer.encoder.layers.1.self_attn.in_proj_weight', 'transformer.encoder.layers.1.self_attn.in_proj_bias', 'transformer.encoder.layers.1.self_attn.out_proj.weight', 'transformer.encoder.layers.1.self_attn.out_proj.bias', 'transformer.encoder.layers.1.linear1.weight', 'transformer.encoder.layers.1.linear1.bias', 'transformer.encoder.layers.1.linear2.weight', 'transformer.encoder.layers.1.linear2.bias', 'transformer.encoder.layers.1.norm1.weight', 'transformer.encoder.layers.1.norm1.bias', 'transformer.encoder.layers.1.norm2.weight', 'transformer.encoder.layers.1.norm2.bias', 'transformer.encoder.layers.2.self_attn.in_proj_weight', 'transformer.encoder.layers.2.self_attn.in_proj_bias', 'transformer.encoder.layers.2.self_attn.out_proj.weight', 'transformer.encoder.layers.2.self_attn.out_proj.bias', 'transformer.encoder.layers.2.linear1.weight', 'transformer.encoder.layers.2.linear1.bias', 'transformer.encoder.layers.2.linear2.weight', 'transformer.encoder.layers.2.linear2.bias', 'transformer.encoder.layers.2.norm1.weight', 'transformer.encoder.layers.2.norm1.bias', 'transformer.encoder.layers.2.norm2.weight', 'transformer.encoder.layers.2.norm2.bias', 'transformer.encoder.layers.3.self_attn.in_proj_weight', 'transformer.encoder.layers.3.self_attn.in_proj_bias', 'transformer.encoder.layers.3.self_attn.out_proj.weight', 'transformer.encoder.layers.3.self_attn.out_proj.bias', 'transformer.encoder.layers.3.linear1.weight', 'transformer.encoder.layers.3.linear1.bias', 'transformer.encoder.layers.3.linear2.weight', 'transformer.encoder.layers.3.linear2.bias', 'transformer.encoder.layers.3.norm1.weight', 'transformer.encoder.layers.3.norm1.bias', 'transformer.encoder.layers.3.norm2.weight', 'transformer.encoder.layers.3.norm2.bias', 'transformer.encoder.layers.4.self_attn.in_proj_weight', 'transformer.encoder.layers.4.self_attn.in_proj_bias', 'transformer.encoder.layers.4.self_attn.out_proj.weight', 'transformer.encoder.layers.4.self_attn.out_proj.bias', 'transformer.encoder.layers.4.linear1.weight', 'transformer.encoder.layers.4.linear1.bias', 'transformer.encoder.layers.4.linear2.weight', 'transformer.encoder.layers.4.linear2.bias', 'transformer.encoder.layers.4.norm1.weight', 'transformer.encoder.layers.4.norm1.bias', 'transformer.encoder.layers.4.norm2.weight', 'transformer.encoder.layers.4.norm2.bias', 'transformer.encoder.layers.5.self_attn.in_proj_weight', 'transformer.encoder.layers.5.self_attn.in_proj_bias', 'transformer.encoder.layers.5.self_attn.out_proj.weight', 'transformer.encoder.layers.5.self_attn.out_proj.bias', 'transformer.encoder.layers.5.linear1.weight', 'transformer.encoder.layers.5.linear1.bias', 'transformer.encoder.layers.5.linear2.weight', 'transformer.encoder.layers.5.linear2.bias', 'transformer.encoder.layers.5.norm1.weight', 'transformer.encoder.layers.5.norm1.bias', 'transformer.encoder.layers.5.norm2.weight', 'transformer.encoder.layers.5.norm2.bias', 'transformer.encoder.layers.6.self_attn.in_proj_weight', 'transformer.encoder.layers.6.self_attn.in_proj_bias', 'transformer.encoder.layers.6.self_attn.out_proj.weight', 'transfo ...
# Loading train dataset...
# CSV: /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/Data/2_final_project_updated_names_train_linear.csv
#  * Images - Train Root Directory: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/train
# Unique labels in column 'Pneumonia': [1 0]
# Loading test dataset...
# CSV: /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/Data/2_final_project_updated_names_test_linear.csv
#  * Images - Test Root Directory: /tmp/CheXpert_dataset/CheXpert_reduced_dataset_split_v3/test
# Unique labels in column 'Pneumonia': [1 0]
# [2025-12-04 06:48:03] Starting MoCo backbone testing...
# Extracting the ViTMoCo model (new architecture)...
# [2025-12-04 06:48:03] Model Keys: odict_keys(['queue', 'queue_ptr', 'patch_embed.proj.0.weight', 'patch_embed.proj.0.bias', 'patch_embed.proj.2.weight', 'patch_embed.proj.2.bias', 'patch_embed.proj.4.weight', 'patch_embed.proj.4.bias', 'pos_encoding.pos_embed', 'pos_encoding.cls_token', 'transformer.encoder.layers.0.self_attn.in_proj_weight', 'transformer.encoder.layers.0.self_attn.in_proj_bias', 'transformer.encoder.layers.0.self_attn.out_proj.weight', 'transformer.encoder.layers.0.self_attn.out_proj.bias', 'transformer.encoder.layers.0.linear1.weight', 'transformer.encoder.layers.0.linear1.bias', 'transformer.encoder.layers.0.linear2.weight', 'transformer.encoder.layers.0.linear2.bias', 'transformer.encoder.layers.0.norm1.weight', 'transformer.encoder.layers.0.norm1.bias', 'transformer.encoder.layers.0.norm2.weight', 'transformer.encoder.layers.0.norm2.bias', 'transformer.encoder.layers.1.self_attn.in_proj_weight', 'transformer.encoder.layers.1.self_attn.in_proj_bias', 'transformer.encoder.layers.1.self_attn.out_proj.weight', 'transformer.encoder.layers.1.self_attn.out_proj.bias', 'transformer.encoder.layers.1.linear1.weight', 'transformer.encoder.layers.1.linear1.bias', 'transformer.encoder.layers.1.linear2.weight', 'transformer.encoder.layers.1.linear2.bias', 'transformer.encoder.layers.1.norm1.weight', 'transformer.encoder.layers.1.norm1.bias', 'transformer.encoder.layers.1.norm2.weight', 'transformer.encoder.layers.1.norm2.bias', 'transformer.encoder.layers.2.self_attn.in_proj_weight', 'transformer.encoder.layers.2.self_attn.in_proj_bias', 'transformer.encoder.layers.2.self_attn.out_proj.weight', 'transformer.encoder.layers.2.self_attn.out_proj.bias', 'transformer.encoder.layers.2.linear1.weight', 'transformer.encoder.layers.2.linear1.bias', 'transformer.encoder.layers.2.linear2.weight', 'transformer.encoder.layers.2.linear2.bias', 'transformer.encoder.layers.2.norm1.weight', 'transformer.encoder.layers.2.norm1.bias', 'transformer.encoder.layers.2.norm2.weight', 'transformer.encoder.layers.2.norm2.bias', 'transformer.encoder.layers.3.self_attn.in_proj_weight', 'transformer.encoder.layers.3.self_attn.in_proj_bias', 'transformer.encoder.layers.3.self_attn.out_proj.weight', 'transformer.encoder.layers.3.self_attn.out_proj.bias', 'transformer.encoder.layers.3.linear1.weight', 'transformer.encoder.layers.3.linear1.bias', 'transformer.encoder.layers.3.linear2.weight', 'transformer.encoder.layers.3.linear2.bias', 'transformer.encoder.layers.3.norm1.weight', 'transformer.encoder.layers.3.norm1.bias', 'transformer.encoder.layers.3.norm2.weight', 'transformer.encoder.layers.3.norm2.bias', 'transformer.encoder.layers.4.self_attn.in_proj_weight', 'transformer.encoder.layers.4.self_attn.in_proj_bias', 'transformer.encoder.layers.4.self_attn.out_proj.weight', 'transformer.encoder.layers.4.self_attn.out_proj.bias', 'transformer.encoder.layers.4.linear1.weight', 'transformer.encoder.layers.4.linear1.bias', 'transformer.encoder.layers.4.linear2.weight', 'transformer.encoder.layers.4.linear2.bias', 'transformer.encoder.layers.4.norm1.weight', 'transformer.encoder.layers.4.norm1.bias', 'transformer.encoder.layers.4.norm2.weight', 'transformer.encoder.layers.4.norm2.bias', 'transformer.encoder.layers.5.self_attn.in_proj_weight', 'transformer.encoder.layers.5.self_attn.in_proj_bias', 'transformer.encoder.layers.5.self_attn.out_proj.weight', 'transformer.encoder.layers.5.self_attn.out_proj.bias', 'transformer.encoder.layers.5.linear1.weight', 'transformer.encoder.layers.5.linear1.bias', 'transformer.encoder.layers.5.linear2.weight', 'transformer.encoder.layers.5.linear2.bias', 'transformer.encoder.layers.5.norm1.weight', 'transformer.encoder.layers.5.norm1.bias', 'transformer.encoder.layers.5.norm2.weight', 'transformer.encoder.layers.5.norm2.bias', 'transformer.encoder.layers.6.self_attn.in_proj_weight', 'transformer.encoder.layers.6.self_attn.in_proj_bias', 'transformer.encoder.layers.6.self_attn.out_proj.weight', 'transformer.encoder.layer ...
# [2025-12-04 06:48:03] Starting linear evaluation for 10 epochs...
# Epoch 0/9: 100% 131/131 [01:02<00:00,  2.08it/s, loss=22.8]
# [2025-12-04 06:50:24] Epoch 1/10, Avg. Running Loss: 7.609862', Train Acc:32.70% Test Acc: 17.77%
# Epoch 1/9: 100% 131/131 [01:03<00:00,  2.06it/s, loss=0.0206]
# [2025-12-04 06:52:44] Epoch 2/10, Avg. Running Loss: 8.491882', Train Acc:32.71% Test Acc: 17.77%
# Epoch 2/9: 100% 131/131 [01:03<00:00,  2.06it/s, loss=40.7]
# [2025-12-04 06:55:05] Epoch 3/10, Avg. Running Loss: 6.113725', Train Acc:67.30% Test Acc: 82.23%
# Epoch 3/9: 100% 131/131 [01:03<00:00,  2.06it/s, loss=32.2]
# [2025-12-04 06:57:26] Epoch 4/10, Avg. Running Loss: 10.216507', Train Acc:39.42% Test Acc: 28.84%
# Epoch 4/9: 100% 131/131 [01:03<00:00,  2.06it/s, loss=16.8]
# [2025-12-04 06:59:47] Epoch 5/10, Avg. Running Loss: 13.801026', Train Acc:67.30% Test Acc: 82.23%
# Epoch 5/9: 100% 131/131 [01:03<00:00,  2.06it/s, loss=3.53]
# [2025-12-04 07:02:08] Epoch 6/10, Avg. Running Loss: 5.820257', Train Acc:67.30% Test Acc: 82.23%
# Epoch 6/9: 100% 131/131 [01:03<00:00,  2.06it/s, loss=12.3]
# [2025-12-04 07:04:29] Epoch 7/10, Avg. Running Loss: 8.466195', Train Acc:66.31% Test Acc: 80.06%
# Epoch 7/9: 100% 131/131 [01:03<00:00,  2.06it/s, loss=6.17]
# [2025-12-04 07:06:50] Epoch 8/10, Avg. Running Loss: 9.924735', Train Acc:63.98% Test Acc: 75.54%
# Epoch 8/9: 100% 131/131 [01:03<00:00,  2.06it/s, loss=0.000171]
# [2025-12-04 07:09:11] Epoch 9/10, Avg. Running Loss: 6.597820', Train Acc:67.30% Test Acc: 82.23%
# Epoch 9/9: 100% 131/131 [01:03<00:00,  2.06it/s, loss=6.2e-6]
# [2025-12-04 07:11:31] Epoch 10/10, Avg. Running Loss: 6.203107', Train Acc:67.30% Test Acc: 82.23%
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [2025-12-04 07:11:45] Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90      2800
#            1       0.00      0.00      0.00       605
#
#     accuracy                           0.82      3405
#    macro avg       0.41      0.50      0.45      3405
# weighted avg       0.68      0.82      0.74      3405
#
# [2025-12-04 07:11:45] Confusion Matrix:
# [[2800    0]
#  [ 605    0]]
# [2025-12-04 07:11:45] Saved confusion matrix to /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts/confusion_matrix_20251204_071131.png
# [2025-12-04 07:11:45] MoCo backbone testing complete!
# [2025-12-04 07:11:45] MoCo backbone testing complete!!
# [2025-12-04 07:11:45] Saved testing stats to /content/drive/MyDrive/Colab Notebooks/7_Py_DL/FP/artifacts//test_stats.json
